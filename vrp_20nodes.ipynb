# %% [markdown]
# In this code, I try to solve the work events generated from Zezhou's code but failed.

# %%
from gurobipy import *
import numpy as np

# %%
# h = np.zeros([6,6,5])
# x=h
# w2 = np.zeros([6,4])
# w=w2
flag=False

# %%
n=19
nc=10
large=1000
v=40

# %% [markdown]
# vrp20.txt contains the distance of work events generated from Zezhou's code

# %%
f = open('vrp20.txt')
d ={}
count = 0
for i in f.readlines():
    cur = i.split()
    p1=cur[0]
    p2=cur[1]
    dis=cur[2]
    if p1=="T0End":
        p1=n
    if p2=="T0End":
        p2=n
    if p1=="T0Begin":
        p1=0
    if p2=="T0Begin":
        p2=0
    d[int(p1)+1,int(p2)+1]=float(dis)
    d[int(p2)+1,int(p1)+1]=float(dis)
for i in range(1,n+1):
    d[i,i]=0
d[1,n+1]=0
d[n+1,1]=0

# %%
d
# Out:
# {(2, 3): 124.66485388269444,
#  (3, 2): 124.66485388269444,
#  (2, 4): 171.67946722738685,
#  (4, 2): 171.67946722738685,
#  (2, 5): 169.17079919952334,
#  (5, 2): 169.17079919952334,
#  (2, 6): 259.12315115458756,
#  (6, 2): 259.12315115458756,
#  (2, 7): 233.67709296624938,
#  (7, 2): 233.67709296624938,
#  (2, 8): 39.4903991366562,
#  (8, 2): 39.4903991366562,
#  (2, 9): 179.38307291803184,
#  (9, 2): 179.38307291803184,
#  (2, 10): 195.60395279657135,
#  (10, 2): 195.60395279657135,
#  (2, 11): 75.59319600076986,
#  (11, 2): 75.59319600076986,
#  (2, 12): 43.679858493330336,
#  (12, 2): 43.679858493330336,
#  (2, 13): 238.92560126352274,
#  (13, 2): 238.92560126352274,
#  (2, 14): 10.743406474942581,
#  (14, 2): 10.743406474942581,
#  (2, 15): 148.05358803426606,
#  (15, 2): 148.05358803426606,
#  (2, 16): 318.85149515965907,
#  (16, 2): 318.85149515965907,
#  (2, 17): 2.9159394612185494,
#  (17, 2): 2.9159394612185494,
#  (2, 18): 35.23055484835513,
#  (18, 2): 35.23055484835513,
#  (2, 19): 286.87082093519257,
#  (19, 2): 286.87082093519257,
#  (2, 20): 38.10990531417834,
#  (20, 2): 38.10990531417834,
#  (3, 4): 47.01461334469241,
#  (4, 3): 47.01461334469241,
#  (3, 5): 44.5059453168289,
#  (5, 3): 44.5059453168289,
#  (3, 6): 134.4582972718931,
#  (6, 3): 134.4582972718931,
#  (3, 7): 109.01223908355493,
#  (7, 3): 109.01223908355493,
#  (3, 8): 85.17445474603825,
#  (8, 3): 85.17445474603825,
#  (3, 9): 54.7182190353374,
#  (9, 3): 54.7182190353374,
#  (3, 10): 70.9390989138769,
#  (10, 3): 70.9390989138769,
#  (3, 11): 49.071657881924594,
#  (11, 3): 49.071657881924594,
#  (3, 12): 80.98499538936412,
#  (12, 3): 80.98499538936412,
#  (3, 13): 114.26074738082829,
#  (13, 3): 114.26074738082829,
#  (3, 14): 113.92144740775187,
#  (14, 3): 113.92144740775187,
#  (3, 15): 23.38873415157161,
#  (17, 17): 0,
#  (18, 18): 0,
#  (19, 19): 0,
#  (1, 20): 0,
#  (20, 1): 0}

# %%
temp= [(1,
  {'property': 'WE',
   'label': '1',
   'coord': (38.10990531417834, 3.969635532994696)}),
 (2,
  {'property': 'WE',
   'label': '2',
   'coord': (162.7747591968728, 4.818926590157665)}),
 (3,
  {'property': 'WE',
   'label': '3',
   'coord': (209.7893725415652, 6.085251374069557)}),
 (4,
  {'property': 'WE',
   'label': '4',
   'coord': (207.2807045137017, 7.002968866328018)}),
 (5,
  {'property': 'WE',
   'label': '5',
   'coord': (297.2330564687659, 7.060074190476342)}),
 (6,
  {'property': 'WE',
   'label': '6',
   'coord': (271.7869982804277, 7.56007419047634)}),
 (7,
  {'property': 'WE',
   'label': '7',
   'coord': (77.60030445083454, 8.077274160609154)}),
 (8,
  {'property': 'WE',
   'label': '8',
   'coord': (217.4929782322102, 9.657790924636965)}),
 (9,
  {'property': 'WE',
   'label': '9',
   'coord': (233.7138581107497, 10.9272741606093)}),
 (10,
  {'property': 'WE',
   'label': '10',
   'coord': (113.7031013149482, 11.2682918521201)}),
 (11,
  {'property': 'WE',
   'label': '11',
   'coord': (81.78976380750868, 11.29340752380983)}),
 (12,
  {'property': 'WE',
   'label': '12',
   'coord': (277.0355065777011, 11.37875708491245)}),
 (13,
  {'property': 'WE',
   'label': '13',
   'coord': (48.85331178912092, 11.93892464493225)}),
 (14,
  {'property': 'WE',
   'label': '14',
   'coord': (186.1634933484444, 12.37596922394234)}),
 (15,
  {'property': 'WE',
   'label': '15',
   'coord': (356.9614004738374, 13.17727416060941)}),
 (16,
  {'property': 'WE',
   'label': '16',
   'coord': (41.02584477539689, 14.17402900804451)}),
 (17,
  {'property': 'WE',
   'label': '17',
   'coord': (2.879350465823205, 15.60930255727584)}),
 (18,
  {'property': 'WE',
   'label': '18',
   'coord': (324.9807262493709, 16.27225797826577)})]
   
   
a=[0]
for i in temp:
    p=i[0]+1
    t=i[1]['coord'][1]
    a.append(t)
a.append(24)
tim=12
b=[i+tim for i in a]
b
# Out:
# [12,
#  15.969635532994696,
#  16.818926590157666,
#  18.085251374069557,
#  19.00296886632802,
#  19.060074190476342,
#  19.56007419047634,
#  20.077274160609154,
#  21.657790924636963,
#  22.9272741606093,
#  23.2682918521201,
#  23.29340752380983,
#  23.37875708491245,
#  23.93892464493225,
#  24.37596922394234,
#  25.17727416060941,
#  26.17402900804451,
#  27.60930255727584,
#  28.27225797826577,
#  36]

# %%
# x[1,4,1] = 1
# x[4,2,1] = 1
# x[2,3,1] = 1
# x[3,5,1] = 1

# w[1,1] = 0
# w[4,1] = 0.975
# w[2,1] = 4.3
# w[3,1] = 7.525
# w[5,1] = 10.65
# obj = quicksum(quicksum(x[1,j,c]for c in range(1,4)) for j in range(1,6))
# print(obj)

# %%
myModel = Model("vrp")
myModel.update()
# Out:
# Academic license - for non-commercial use only

# %% [markdown]
# ## Adding variables

# %%
x = myModel.addVars(range(1,n+1),range(1,n+1),range(1,nc+1),vtype=GRB.BINARY,lb=0.0,name='x')
w = myModel.addVars(range(1,n+1),range(1,nc+1),vtype=GRB.CONTINUOUS,lb=0.0,name='w')

# %% [markdown]
# ## Adding constraints

# %% [markdown]
# $$
# w_{0c}\geq F,\ w_{0\prime c}\le L,\ where\ F=0\ and\ L=12,\forall c
# $$

# %%
for c in range(1,nc+1):
    myModel.addConstr(w[1,c]>=0)
    myModel.addConstr(w[n,c]<=12)
    if flag:
        print(c,'   ',w2[1,c]>=0,w2[n,c]<=12)

# %% [markdown]
# $$
# \sum_{j} X_{0jc}\le1,\forall c
# $$

# %%
for c in range(1,nc+1):
    con1 = quicksum(x[1,j,c] for j in range(1,n+1))
    myModel.addConstr(con1 <= 1)
    if flag:
        print(quicksum(h[1,j,c] for j in range(1,n+1)))

# %% [markdown]
# $$
# \sum_{j} X_{j0\prime c}\le1,\ \forall c
# $$

# %%
for c in range(1,nc+1):
    con2 = quicksum(x[j,n,c] for j in range(1,n+1))
    myModel.addConstr(con2 <= 1) 
    if flag:
        print(quicksum(h[j,n,c] for j in range(1,n+1)))

# %% [markdown]
# $$
# \sum_{j\neq0\prime}^{N}X_{jic}-\sum_{j\neq0}^{N}X_{ijc}=0,\ \forall i=1,...,N,\ \forall c
# $$

# %%
for i in range(2,n):
    for c in range(1,nc+1):
        sum1 = quicksum(x[j,i,c] for j in range(1,n))
        sum2 = quicksum(x[i,j,c] for j in range(2,n+1))
        myModel.addConstr(sum1 - sum2 == 0) 
        if flag:
            print(i,c,quicksum(h[j,i,c] for j in range(1,n))-quicksum(h[i,j,c] for j in range(2,n+1)))

# %% [markdown]
# $$
# \sum_{j\neq0}{\sum_{c} X_{ijc}=1,}\forall i=1,...,N
# $$

# %%
for i in range(2,n):
    sum3 = quicksum(quicksum(x[i,j,c] for c in range(1,nc+1)) for j in range(2,n+1))
    myModel.addConstr(sum3 == 1)
    if flag:
        print(quicksum(quicksum(h[i,j,c] for c in range(1,nc+1)) for j in range(2,n+1)))

# %% [markdown]
# $$
# \sum_{i\neq0\prime}{\sum_{c} X_{ijc}=1,}\forall j=1,...N
# $$

# %%
for j in range(2,n):
    sum4 = quicksum(quicksum(x[i,j,c] for c in range(1,nc+1)) for i in range(1,n))
    myModel.addConstr(sum4 == 1)
    if flag:
        print(quicksum(quicksum(h[i,j,c] for c in range(1,nc+1)) for i in range(1,n)))

# %% [markdown]
# $$
# \sum_{i}\sum_{j}{X_{ijc}\times\frac{d_{ij}}{v}\le12,\ \forall c}
# $$

# %%
for c in range(1,nc+1):
    con3 = quicksum(quicksum(x[i,j,c]*d[i,j]/v for j in range(1,n+1)) for i in range(1,n+1))
    myModel.addConstr(con3 <= 12) 
    if flag:
        print(quicksum(quicksum(h[i,j,c]*d[i,j]/v for j in range(1,n+1)) for i in range(1,n+1)))

# %% [markdown]
# $$
# a_i\sum_{j} X_{ijc}\le w_{ic}\le b_i\sum_{j}{X_{ijc},\ \forall i}=1,...N,\forall c
# $$

# %%
for c in range(1,nc+1):
    for i in range(2,n):
        equ1 = a[i-1]*quicksum(x[i,j,c] for j in range(1,n+1))
        equ2 = b[i-1]*quicksum(x[i,j,c] for j in range(1,n+1))
        myModel.addConstr(w[i,c] >= equ1) 
        myModel.addConstr(w[i,c] <= equ2) 
        if flag:
            print(w2[i,c]-a[i-1]*quicksum(h[i,j,c] for j in range(1,n+1)),b[i-1]*quicksum(h[i,j,c] for j in range(1,n+1))-w2[i,c] ,i,c)

# %% [markdown]
# $$
# w_{ic}+s_i+\frac{d_{ij}}{v}-w_{jc}\le B_{ij}(1-X_{ijc}),\ \forall i,j\in{0,0\prime,1,...N},\forall c
# $$

# %%
for c in range(1,nc+1):
    for i in range(1,n+1):
        for j in range(1,n+1):
            myModel.addConstr(w[i,c] + d[i,j]/v - w[j,c] <= large*(1 - x[i,j,c]))
            if flag:
                print(w2[i,c] + d[i,j]/v - w2[j,c] <= large*(1 - h[i,j,c]))
#                 print(w[i,c] + d[i,j]/v - w[j,c])

# %% [markdown]
# $$
# X_{ijc}\neq1\ if\ i=j,\forall c
# $$

# %%
for c in range(1,nc+1):
    for i in range(1,n+1):
        for j in range(1,n+1):
            if i == j:
                myModel.addConstr(x[i,j,c] == 0)
                if flag:
                    print(h[i,j,c])

# %% [markdown]
# $$
# X_{0\prime j c}=0,\ \forall j,\forall c
# $$

# %%
for c in range(1,nc+1):
    for j in range(1,n+1):
        myModel.addConstr(x[n,j,c] == 0)

# %% [markdown]
# $$
# X_{i0c}=0\ \forall i,\forall c
# $$

# %%
for c in range(1,nc+1):
    for i in range(1,n+1):
        myModel.addConstr(x[i,1,c] == 0)

# %% [markdown]
# ## Objective

# %%
myModel.setParam("IterationLimit",10000000)
# Out:
# Parameter IterationLimit unchanged
#    Value: 10000000.0  Min: 0.0  Max: 1e+100  Default: 1e+100

# %% [markdown]
# $$
# min\ \sum_{j}\sum_{c} X_{0jc}
# $$

# %%
obj = quicksum(quicksum(x[1,j,c]for c in range(1,nc+1)) for j in range(1,n+1))
myModel.setObjective(obj)

# %%
obj
# Out:
# <gurobi.LinExpr: x[1,1,1] + x[1,1,2] + x[1,1,3] + x[1,1,4] + x[1,1,5] + x[1,1,6] + x[1,1,7] + x[1,1,8] + x[1,1,9] + x[1,1,10] + x[1,2,1] + x[1,2,2] + x[1,2,3] + x[1,2,4] + x[1,2,5] + x[1,2,6] + x[1,2,7] + x[1,2,8] + x[1,2,9] + x[1,2,10] + x[1,3,1] + x[1,3,2] + x[1,3,3] + x[1,3,4] + x[1,3,5] + x[1,3,6] + x[1,3,7] + x[1,3,8] + x[1,3,9] + x[1,3,10] + x[1,4,1] + x[1,4,2] + x[1,4,3] + x[1,4,4] + x[1,4,5] + x[1,4,6] + x[1,4,7] + x[1,4,8] + x[1,4,9] + x[1,4,10] + x[1,5,1] + x[1,5,2] + x[1,5,3] + x[1,5,4] + x[1,5,5] + x[1,5,6] + x[1,5,7] + x[1,5,8] + x[1,5,9] + x[1,5,10] + x[1,6,1] + x[1,6,2] + x[1,6,3] + x[1,6,4] + x[1,6,5] + x[1,6,6] + x[1,6,7] + x[1,6,8] + x[1,6,9] + x[1,6,10] + x[1,7,1] + x[1,7,2] + x[1,7,3] + x[1,7,4] + x[1,7,5] + x[1,7,6] + x[1,7,7] + x[1,7,8] + x[1,7,9] + x[1,7,10] + x[1,8,1] + x[1,8,2] + x[1,8,3] + x[1,8,4] + x[1,8,5] + x[1,8,6] + x[1,8,7] + x[1,8,8] + x[1,8,9] + x[1,8,10] + x[1,9,1] + x[1,9,2] + x[1,9,3] + x[1,9,4] + x[1,9,5] + x[1,9,6] + x[1,9,7] + x[1,9,8] + x[1,9,9] + x[1,9,10] + x[1,10,1] + x[1,10,2] + x[1,10,3] + x[1,10,4] + x[1,10,5] + x[1,10,6] + x[1,10,7] + x[1,10,8] + x[1,10,9] + x[1,10,10] + x[1,11,1] + x[1,11,2] + x[1,11,3] + x[1,11,4] + x[1,11,5] + x[1,11,6] + x[1,11,7] + x[1,11,8] + x[1,11,9] + x[1,11,10] + x[1,12,1] + x[1,12,2] + x[1,12,3] + x[1,12,4] + x[1,12,5] + x[1,12,6] + x[1,12,7] + x[1,12,8] + x[1,12,9] + x[1,12,10] + x[1,13,1] + x[1,13,2] + x[1,13,3] + x[1,13,4] + x[1,13,5] + x[1,13,6] + x[1,13,7] + x[1,13,8] + x[1,13,9] + x[1,13,10] + x[1,14,1] + x[1,14,2] + x[1,14,3] + x[1,14,4] + x[1,14,5] + x[1,14,6] + x[1,14,7] + x[1,14,8] + x[1,14,9] + x[1,14,10] + x[1,15,1] + x[1,15,2] + x[1,15,3] + x[1,15,4] + x[1,15,5] + x[1,15,6] + x[1,15,7] + x[1,15,8] + x[1,15,9] + x[1,15,10] + x[1,16,1] + x[1,16,2] + x[1,16,3] + x[1,16,4] + x[1,16,5] + x[1,16,6] + x[1,16,7] + x[1,16,8] + x[1,16,9] + x[1,16,10] + x[1,17,1] + x[1,17,2] + x[1,17,3] + x[1,17,4] + x[1,17,5] + x[1,17,6] + x[1,17,7] + x[1,17,8] + x[1,17,9] + x[1,17,10] + x[1,18,1] + x[1,18,2] + x[1,18,3] + x[1,18,4] + x[1,18,5] + x[1,18,6] + x[1,18,7] + x[1,18,8] + x[1,18,9] + x[1,18,10] + x[1,19,1] + x[1,19,2] + x[1,19,3] + x[1,19,4] + x[1,19,5] + x[1,19,6] + x[1,19,7] + x[1,19,8] + x[1,19,9] + x[1,19,10]>

# %% [markdown]
# ## Optimization

# %%
myModel.optimize()
# Out:
# Optimize a model with 4774 rows, 3800 columns and 33540 nonzeros
# Variable types: 190 continuous, 3610 integer (3610 binary)
# Coefficient statistics:
#   Matrix range     [6e-02, 1e+03]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+03]
# Presolve removed 1430 rows and 860 columns
# Presolve time: 0.21s
# Presolved: 3344 rows, 2940 columns, 54289 nonzeros
# Variable types: 170 continuous, 2770 integer (2770 binary)
#
# Root relaxation: objective 0.000000e+00, 612 iterations, 0.07 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.00000    0   40          -    0.00000      -     -    0s
#      0     0    0.00000    0   58          -    0.00000      -     -    0s
#      0     0    0.00000    0   45          -    0.00000      -     -    0s
#      0     0    0.00000    0   20          -    0.00000      -     -    1s
#      0     0    0.00000    0   47          -    0.00000      -     -    1s
#      0     0    0.00000    0   21          -    0.00000      -     -    1s
#      0     0    0.00000    0   17          -    0.00000      -     -    1s
#      0     0    0.00000    0   17          -    0.00000      -     -    1s
#      0     0    0.00000    0   12          -    0.00000      -     -    1s
#      0     0    0.00000    0   23          -    0.00000      -     -    2s
#      0     0    0.00000    0   39          -    0.00000      -     -    2s
#      0     0    0.00000    0   18          -    0.00000      -     -    2s
#      0     0    0.00000    0   18          -    0.00000      -     -    2s
#      0     2    0.00000    0   18          -    0.00000      -     -    3s
#    130    90    0.00000    7   46          -    0.00000      -   108    5s
#   1331   668    0.00000   19   18          -    0.00000      -  74.7   10s
#   1349   680    0.00000   18   56          -    0.00000      -  73.7   15s
#   1390   694 infeasible   19               -    0.00000      -  90.6   20s
#   1662   632 infeasible   31               -    0.00000      -  90.9   25s
#   2083   524    0.00000   37   31          -    0.00000      -  93.1   30s
#   3674   235    0.00000   42   29          -    0.00000      -  69.7   35s
#   5061   521 infeasible   29               -    0.00000      -  63.3   40s
#   6904   540 infeasible   39               -    0.00000      -  56.7   45s
#   9210   693    0.00000   50   18          -    0.00000      -  51.3   50s
#  11764   677 infeasible   43               -    0.00000      -  46.2   63s
#  11879   671    0.00000   21   33          -    0.00000      -  46.2   65s
#  13234   929 infeasible   34               -    0.00000      -  45.2   70s
#  15281  1491    0.00000   27   41          -    0.00000      -  44.3   75s
#  18128  2414 infeasible   88               -    0.00000      -  40.8   80s
#  20146  2469 infeasible   78               -    0.00000      -  38.8   85s
#  21864  1932    0.00000   40   28          -    0.00000      -  38.3   90s
#  22456  2056 infeasible   95               -    0.00000      -  38.0  123s
#  22838  1940 infeasible   71               -    0.00000      -  38.0  125s
#  26312  3074 infeasible   79               -    0.00000      -  35.0  130s
#  31317  3493 infeasible  115               -    0.00000      -  32.6  135s
#  33366  3479 infeasible   83               -    0.00000      -  32.1  146s
#  36582  3471 infeasible  130               -    0.00000      -  30.9  150s
#  40398  3628 infeasible   86               -    0.00000      -  30.3  155s
#  41531  3203 infeasible   84               -    0.00000      -  30.2  160s
#  44135  3532 infeasible  118               -    0.00000      -  29.8  172s
#  46338  3591    0.00000  135   29          -    0.00000      -  29.4  175s
#  50518  4460 infeasible   87               -    0.00000      -  28.6  180s
#  54599  6110 infeasible   96               -    0.00000      -  27.9  192s
#  57690  7261    0.00000  117   32          -    0.00000      -  27.5  195s
#  61829  7114 infeasible   96               -    0.00000      -  27.0  200s
#  63329  6974 infeasible   97               -    0.00000      -  26.8  205s
#  184662 15463 infeasible  100               -    0.00000      -  26.8  470s
#  185193 15510 infeasible  194               -    0.00000      -  26.9  480s
#  188595 15486 infeasible  177               -    0.00000      -  26.9  485s
#  191095 15647 infeasible  125               -    0.00000      -  27.1  490s
#  194208 16192 infeasible  159               -    0.00000      -  27.1  495s
#  195946 16445 infeasible  167               -    0.00000      -  27.0  505s
#  199386 15831    0.00000   71   21          -    0.00000      -  27.0  510s
#  202597 15773 infeasible   45               -    0.00000      -  27.0  515s
#  205548 15443 infeasible   80               -    0.00000      -  27.0  520s
#  206260 15750 infeasible  109               -    0.00000      -  27.0  529s
#  206623 15428 infeasible   75               -    0.00000      -  27.0  530s
#  210605 15644 infeasible  111               -    0.00000      -  27.0  535s
#  214635 16344 infeasible  112               -    0.00000      -  26.9  540s
#  217062 16533    0.00000   96   30          -    0.00000      -  26.9  551s
#  220433 16356 infeasible  124               -    0.00000      -  26.9  555s
#  224420 15796 infeasible  116               -    0.00000      -  26.8  560s
#  228187 16991 infeasible  134               -    0.00000      -  26.6  572s
#  230430 17148 infeasible  163               -    0.00000      -  26.6  575s
#  234611 17423 infeasible   68               -    0.00000      -  26.6  580s
#  238299 17947 infeasible  142               -    0.00000      -  26.5  585s
#  238399 17900 infeasible   72               -    0.00000      -  26.5  593s
#  239570 17752 infeasible  135               -    0.00000      -  26.5  595s
#  242795 17983 infeasible  173               -    0.00000      -  26.6  600s
#  245316 17317    0.00000  119   27          -    0.00000      -  26.6  605s
#  249532 18122 infeasible  184               -    0.00000      -  26.6  618s
#  250627 18080 infeasible  148               -    0.00000      -  26.6  620s
#  254060 18053 infeasible  160               -    0.00000      -  26.7  625s
#  256359 17373    0.00000   63   23          -    0.00000      -  26.8  630s
#  259911 17300 infeasible  123               -    0.00000      -  26.7  642s
#  261406 17073 infeasible  145               -    0.00000      -  26.7  645s
#  265591 17485 infeasible  169               -    0.00000      -  26.7  650s
#  268766 17486    0.00000  135   33          -    0.00000      -  26.6  655s
#  270510 18281 infeasible  100               -    0.00000      -  26.6  664s
#  270782 18102 infeasible  107               -    0.00000      -  26.6  665s
#  275540 18650 infeasible  149               -    0.00000      -  26.4  670s
#  279429 19286 infeasible   82               -    0.00000      -  26.4  675s
#  281145 19391 infeasible  113               -    0.00000      -  26.4  685s
#  283627 18922    0.00000   44   24          -    0.00000      -  26.4  690s
#  287257 18698 infeasible  124               -    0.00000      -  26.4  695s
#  290750 19631 infeasible  135               -    0.00000      -  26.4  700s
#  292037 19271 infeasible   74               -    0.00000      -  26.4  710s
#  295578 19521 infeasible   83               -    0.00000      -  26.4  715s
#  300274 21245    0.00000  145   35          -    0.00000      -  26.3  720s
#  302369 21775    0.11368  105   25          -    0.00000      -  26.3  731s
#  304630 21993    0.00000  163   31          -    0.00000      -  26.3  735s
#  309688 23691 infeasible  110               -    0.00000      -  26.2  740s
#  313090 24923 infeasible   97               -    0.00000      -  26.1  753s
#  313772 24656    0.00000  166   23          -    0.00000      -  26.1  755s
#  316676 24794 infeasible  143               -    0.00000      -  26.1  760s
#  319191 24947 infeasible  143               -    0.00000      -  26.1  765s
#  322820 25472    0.00000  115   25          -    0.00000      -  26.1  770s
#  323483 25555 infeasible  145               -    0.00000      -  26.1  780s
#  326503 25920 infeasible  116               -    0.00000      -  26.0  785s
#  328839 25569    0.00000   71   27          -    0.00000      -  26.1  790s
#  332159 26215 infeasible   99               -    0.00000      -  26.0  795s
#  333720 26621 infeasible  171               -    0.00000      -  26.1  807s
#  334397 26059    0.00000   89   26          -    0.00000      -  26.1  810s
#  336914 26192 infeasible   75               -    0.00000      -  26.2  815s
#  339289 25924 infeasible   75               -    0.00000      -  26.2  820s
#  342728 26094 infeasible  133               -    0.00000      -  26.2  825s
#  344204 26482 infeasible  127               -    0.00000      -  26.2  836s
#  346777 26332 infeasible  107               -    0.00000      -  26.1  840s
#  349116 26313 infeasible  109               -    0.00000      -  26.1  845s
#  352339 26530    0.00000  117   31          -    0.00000      -  26.1  850s
#  355604 27462 infeasible  174               -    0.00000      -  26.0  862s
#  357100 27514 infeasible  214               -    0.00000      -  26.0  865s
#  359571 27734 infeasible  196               -    0.00000      -  26.1  870s
#  362471 27769 infeasible  212               -    0.00000      -  26.1  875s
#  364645 27597    0.00000  163   24          -    0.00000      -  26.1  880s
#  366701 27632 infeasible  128               -    0.00000      -  26.1  893s
#  367587 27276 infeasible  167               -    0.00000      -  26.1  895s
#  370103 27335 infeasible  116               -    0.00000      -  26.1  900s
#  373351 27840 infeasible   78               -    0.00000      -  26.1  905s
#  375638 27665 infeasible  125               -    0.00000      -  26.1  910s
#  377054 27506    0.00000   69   35          -    0.00000      -  26.1  915s
#  377973 27889 infeasible   70               -    0.00000      -  26.1  926s
#  379803 27787 infeasible   99               -    0.00000      -  26.1  930s
#  382223 27452    0.00000   85   34          -    0.00000      -  26.1  935s
#
# Cutting planes:
#   Gomory: 1
#   Cover: 13
#   Implied bound: 131
#   Projected implied bound: 41
#   Clique: 2
#   MIR: 34
#   StrongCG: 1
#   Flow cover: 234
#   GUB cover: 20
#   Inf proof: 3
#   Zero half: 9
#
# Explored 383128 nodes (10003396 simplex iterations) in 936.55 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 0
#
# Iteration limit reached
# Best objective -, best bound 0.000000000000e+00, gap -

# %%
myModel.ObjBound
# Out:
# 0.0

# %%
for key,i in x.items():
    if i.x == 1:
        print(i)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-35-6d8f5cad797e> in <module>()
#       1 for key,i in x.items():
# ----> 2     if i.x == 1:
#       3         print(i)
#
# var.pxi in gurobipy.Var.__getattr__()
#
# var.pxi in gurobipy.Var.getAttr()
#
# AttributeError: b"Unable to retrieve attribute 'x'"

# %%
for key,i in w.items():
    if i.x != 0:
        print(i)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-36-80b5eb02f98f> in <module>()
#       1 for key,i in w.items():
# ----> 2     if i.x != 0:
#       3         print(i)
#
# var.pxi in gurobipy.Var.__getattr__()
#
# var.pxi in gurobipy.Var.getAttr()
#
# AttributeError: b"Unable to retrieve attribute 'x'"
